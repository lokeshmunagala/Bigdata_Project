# %%
import pandas as pd

# %%
df = pd.read_csv('F:\datasets for big data\owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df1 = df.loc[:, ['location','date','total_cases','new_cases','total_deaths','new_deaths']]

# %%
df1.head()
# Out:
#       location        date  total_cases  new_cases  total_deaths  new_deaths
# 0  Afghanistan  2020-02-24          1.0        1.0           NaN         NaN
# 1  Afghanistan  2020-02-25          1.0        0.0           NaN         NaN
# 2  Afghanistan  2020-02-26          1.0        0.0           NaN         NaN
# 3  Afghanistan  2020-02-27          1.0        0.0           NaN         NaN
# 4  Afghanistan  2020-02-28          1.0        0.0           NaN         NaN

# %%
list1 = ['United States','India','Italy','China','Spain']

# %%
df2 = df1.loc[df['location'].isin(list1)]

# %%
df2
# Out:
#             location        date  total_cases  total_deaths
# 14541          China  2020-01-22        548.0          17.0
# 14542          China  2020-01-23        643.0          18.0
# 14543          China  2020-01-24        920.0          26.0
# 14544          China  2020-01-25       1406.0          42.0
# 14545          China  2020-01-26       2075.0          56.0
# 14546          China  2020-01-27       2877.0          82.0
# 14547          China  2020-01-28       5509.0         131.0
# 14548          China  2020-01-29       6087.0         133.0
# 14549          China  2020-01-30       8141.0         171.0
# 14550          China  2020-01-31       9802.0         213.0
# 14551          China  2020-02-01      11891.0         259.0
# 14552          China  2020-02-02      16630.0         361.0
# 14553          China  2020-02-03      19716.0         425.0
# 14554          China  2020-02-04      23707.0         491.0
# 14555          China  2020-02-05      27440.0         563.0
# ...

# %%
df2.count()
# Out:
# location        2103
# date            2103
# total_cases     2103
# new_cases       2101
# total_deaths    1972
# new_deaths      1971
# dtype: int64

# %%
df2.dropna(subset=['new_deaths'], inplace=True)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.count()
# Out:
# location        1971
# date            1971
# total_cases     1971
# new_cases       1971
# total_deaths    1971
# new_deaths      1971
# dtype: int64

# %%
df2.to_csv('covid-data.csv')
