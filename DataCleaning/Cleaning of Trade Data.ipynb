# %%
import pandas as pd

# %%
df = pd.read_csv('tradedata.csv',encoding='cp1252')
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                        Indicator Category Indicator Code  \
# 0  Merchandise trade - indices and prices     ITS_MTP_AM
# 1  Merchandise trade - indices and prices     ITS_MTP_AM
# 2  Merchandise trade - indices and prices     ITS_MTP_AM
# 3  Merchandise trade - indices and prices     ITS_MTP_AM
# 4  Merchandise trade - indices and prices     ITS_MTP_AM
#
#                                            Indicator  Reporting Economy Code  \
# 0  Merchandise import value chained indices - annual                       0
# 1  Merchandise import value chained indices - annual                       0
# 2  Merchandise import value chained indices - annual                     156
# 3  Merchandise import value chained indices - annual                     156
# 4  Merchandise import value chained indices - annual                     356
#
#   Reporting Economy ISO3A Code Reporting Economy Partner Economy Code  \
# 0                          NaN             World                  000
# ...

# %%
df1 = df.loc[:, ['Indicator','Reporting Economy','Partner Economy','Period','Unit','Year','Value']]

# %%
df1.head()
# Out:
#                                            Indicator Reporting Economy  \
# 0  Merchandise import value chained indices - annual             World
# 1  Merchandise import value chained indices - annual             World
# 2  Merchandise import value chained indices - annual             China
# 3  Merchandise import value chained indices - annual             China
# 4  Merchandise import value chained indices - annual             India
#
#   Partner Economy  Period               Unit  Year    Value
# 0           World  Annual  Previous year=100  2019   97.077
# 1           World  Annual  Previous year=100  2018  110.407
# 2           World  Annual  Previous year=100  2019   97.314
# 3           World  Annual  Previous year=100  2018  115.835
# 4           World  Annual  Previous year=100  2018  114.344

# %%
df1.count()
# Out:
# Indicator            47627
# Reporting Economy    47627
# Partner Economy      47627
# Period               47627
# Unit                 47627
# Year                 47627
# Value                47627
# dtype: int64

# %%
list1 = ['United States of America','India','Italy','China','Spain']

# %%
df2 = df1.loc[df['Reporting Economy'].isin(list1)]

# %%
df2.head()
# Out:
#                                            Indicator Reporting Economy  \
# 2  Merchandise import value chained indices - annual             China
# 3  Merchandise import value chained indices - annual             China
# 4  Merchandise import value chained indices - annual             India
# 5  Merchandise import value chained indices - annual             India
# 6  Merchandise import value chained indices - annual             Italy
#
#   Partner Economy  Period               Unit  Year    Value
# 2           World  Annual  Previous year=100  2019   97.314
# 3           World  Annual  Previous year=100  2018  115.835
# 4           World  Annual  Previous year=100  2018  114.344
# 5           World  Annual  Previous year=100  2019   94.479
# 6           World  Annual  Previous year=100  2018  111.061

# %%
df2.count()
# Out:
# Indicator            47174
# Reporting Economy    47174
# Partner Economy      47174
# Period               47174
# Unit                 47174
# Year                 47174
# Value                47174
# dtype: int64

# %%
list2 = ['Total merchandise imports - monthly','Total merchandise exports - monthly','Commercial services imports of selected economies – monthly','Commercial services exports of selected economies – monthly','Commercial services imports of selected economies (growth) – monthly','Commercial services exports of selected economies (growth) – monthly']

# %%
df3 = df2.loc[df['Indicator'].isin(list2)]

# %%
df3.head()
# Out:
#                                 Indicator Reporting Economy Partner Economy  \
# 1164  Total merchandise imports - monthly             China           World
# 1165  Total merchandise imports - monthly             China           World
# 1166  Total merchandise imports - monthly             China           World
# 1167  Total merchandise imports - monthly             China           World
# 1168  Total merchandise imports - monthly             China           World
#
#         Period               Unit  Year          Value
# 1164   January  Million US dollar  2018  181151.000000
# 1165   January  Million US dollar  2019  179664.207480
# 1166  February  Million US dollar  2019  132368.226112
# 1167  February  Million US dollar  2020  299544.204685
# 1168  February  Million US dollar  2018  138345.000000

# %%
df3.count()
# Out:
# Indicator            7072
# Reporting Economy    7072
# Partner Economy      7072
# Period               7072
# Unit                 7072
# Year                 7072
# Value                7072
# dtype: int64

# %%
df3.to_csv('trade-data.csv',encoding='cp1252')
