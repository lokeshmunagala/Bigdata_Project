# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Notebook files for data cleaning/cleaned data/covid-data.csv')

# %%
df.head(10)
# Out:
#   location       date  total_cases  new_cases  total_deaths  new_deaths
# 0    China  1/23/2020          643         95            18           1
# 1    China  1/24/2020          920        277            26           8
# 2    China  1/25/2020         1406        486            42          16
# 3    China  1/26/2020         2075        669            56          14
# 4    China  1/27/2020         2877        802            82          26
# 5    China  1/28/2020         5509       2632           131          49
# 6    China  1/29/2020         6087        578           133           2
# 7    China  1/30/2020         8141       2054           171          38
# 8    China  1/31/2020         9802       1661           213          42
# 9    China   2/1/2020        11891       2089           259          46

# %%
df.plot()

# %%
x = df.groupby(['location'])
x.head(5)
# df.plot()
# Out:
#            location       date  total_cases  new_cases  total_deaths  \
# 0             China  1/23/2020          643         95            18
# 1             China  1/24/2020          920        277            26
# 2             China  1/25/2020         1406        486            42
# 3             China  1/26/2020         2075        669            56
# 4             China  1/27/2020         2877        802            82
# 425           India  3/11/2020           62          6             1
# 426           India  3/12/2020           73         11             1
# 427           India  3/13/2020           82          9             2
# 428           India  3/14/2020          102         20             2
# 429           India  3/15/2020          113         11             2
# 802           Italy  2/21/2020           20         17             1
# 803           Italy  2/22/2020           62         42             2
# 804           Italy  2/23/2020          155         93             3
# ...

# %%
# df[df['location'] == 'China']['total_cases']
df['date'] =  pd.to_datetime(df['date'],format='%m/%d/%Y')
df.head(10)
# Out:
#   location       date  total_cases  new_cases  total_deaths  new_deaths
# 0    China 2020-01-23          643         95            18           1
# 1    China 2020-01-24          920        277            26           8
# 2    China 2020-01-25         1406        486            42          16
# 3    China 2020-01-26         2075        669            56          14
# 4    China 2020-01-27         2877        802            82          26
# 5    China 2020-01-28         5509       2632           131          49
# 6    China 2020-01-29         6087        578           133           2
# 7    China 2020-01-30         8141       2054           171          38
# 8    China 2020-01-31         9802       1661           213          42
# 9    China 2020-02-01        11891       2089           259          46

# %%
for x in ['China','India','Italy','Spain','United States']:
    plt.plot(df[df['location'] == x]['date'],df[df['location'] == x]['total_cases'],label=x)
plt.legend()
plt.title("Total No:of cases")
plt.show()
