# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.rcParams["figure.figsize"] = (22, 7)

# %%
df1=pd.DataFrame({'x':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  'y':[90.94263051097583,91.63149201688383,89.41079522043675,76.14678899082568,81.47109577221742,84.83651525126179,85.39016115351993,86.95563279492946,88.61423220973784,89.49889462048637,89.1444866920152,87.43278231428002]})
df2=pd.DataFrame({'x':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  'y':[87.71929824561403,85.38011695906432,83.77483443708608,59.09090909090909,70.0,73.62204724409449,75.64575645756457,75.82089552238806,76.75675675675676,79.18781725888326,80.43478260869566,81.08108108108108]})
df3=pd.DataFrame({'x':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  'y':[81.63265306122449,87.27272727272727,77.77777777777779,59.45945945945946,60.60606060606061,81.48148148148148,83.33333333333334,87.8048780487805,83.72093023255815,78.72340425531915,66.66666666666666,78.26086956521739]})
df4=pd.DataFrame({'x':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  'y':[90.9090909090909,90.42904290429043,91.84397163120568,61.92170818505338,68.18181818181817,78.03921568627452,82.77310924369748,86.0082304526749,84.70149253731343,85.61643835616438,85.40145985401459,87.02928870292888]})
df1['Ethnicity']= 'White'
df2['Ethnicity']= 'Black'
df3['Ethnicity']= 'American Indian'
df4['Ethnicity']= 'Asian'
res=pd.concat([df1,df2,df3,df4])
g=sns.barplot(x='x',y='y',data=res,hue='Ethnicity', palette = 'Blues_d')

g.set(ylim=(55, None))
plt.xlabel('Months for the Year 2020')
plt.ylabel('Active Business Percentages')
plt.title('Active Business Ownerships grouped by Ethnicity of the Population')
plt.savefig('ethnicity.png')
plt.show()

# %%
df1=pd.DataFrame({'x':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  'y':[90.93264248704664,91.21691302853215,89.14505283381364,75.28859323028762,80.39018503620274,83.85914919601059,84.73871733966746,86.36105322977836,87.77330767885255,88.4201537147737,88.1819797405367,86.86361947231512]})
df2=pd.DataFrame({'x':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  'y':[87.00980392156863,91.66666666666666,87.73333333333333,62.68656716417911,72.42524916943522,82.78388278388277,84.15492957746478,84.83870967741936,85.21303258145363,89.68058968058969,88.66995073891626,87.96561604584528]})
df1['Resident_status']= 'Native'
df2['Resident_status']= 'Immigrant'
res=pd.concat([df1,df2])
g=sns.barplot(x='x',y='y',data=res,hue='Resident_status', palette = 'Purples')

g.set(ylim=(55, None))
plt.savefig('Resident_status.png')
plt.xlabel('Months for the Year 2020')
plt.ylabel('Active Business Percentages')
plt.title('Active Business Ownerships of the Natives and Immigrants in the US')
plt.show()
